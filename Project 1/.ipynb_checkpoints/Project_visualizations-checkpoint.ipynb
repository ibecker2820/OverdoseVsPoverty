# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
comparison_data = "Resources/comparison.csv"

# %%
comparison_df = pd.read_csv(comparison_data)
comparison_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-134f4be5636c> in <module>
# ----> 1 comparison_df = pd.read_csv(comparison_data)
#       2 comparison_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/comparison.csv'

# %%
#Top ten state overdose rates in 2019
overdose2019_top10 = comparison_df.sort_values(by=['Overdose Rate 2019'], ascending=False).head(10)

#Top ten state overdose rates in 2018
overdose2018_top10 = comparison_df.sort_values(by=['Overdose Rate 2018'], ascending=False).head(10)

#Top ten state overdose rates in 2017
overdose2017_top10 = comparison_df.sort_values(by=['Overdose Rate 2017'], ascending=False).head(10)

#Top ten state overdose rates in 2016
overdose2016_top10 = comparison_df.sort_values(by=['Overdose Rate 2016'], ascending=False).head(10)

#Top ten state overdose rates in 2015
overdose2015_top10 = comparison_df.sort_values(by=['Overdose Rate 2015'], ascending=False).head(10)

# %%
overdose2019_top10
# Out:
#             State  2019  2018  2017  2016  2015  5-Year total  \
# 6     Connecticut  1214  1069  1072   971   800          5126
# 43           Utah   571   624   650   635   646          3126
# 47  West Virginia   870   856   974   884   725          4309
# 19       Maryland  2369  2324  2247  2044  1285         10269
# 34           Ohio  4251  3980  5111  4329  3310         20981
# 37   Pennsylvania  4377  4415  5388  4627  3264         22071
# 20  Massachusetts  2210  2241  2168  2227  1724         10570
# 29     New Jersey  2805  2900  2685  2056  1454         11900
# 41      Tennessee  2089  1823  1776  1630  1457          8775
# 16       Kentucky  1380  1315  1566  1419  1273          6953
#
#     Overdose Rate 2019  Overdose Rate 2018  Overdose Rate 2017  \
# 6             0.126822            0.012036            0.011964
# 43            0.091461            0.021452            0.014691
# 47            0.047873            0.014259            0.014346
# 19            0.039360            0.371854            0.212756
# 34            0.036472            0.581448            0.142190
# 37            0.034218            0.042875            0.325092
# 20            0.032260            0.073588            0.044304
# 29            0.031593            0.041747            0.046589
# 41            0.031136            0.027465            0.056958
# 16            0.031018            0.152148            0.040192
#
#     Overdose Rate 2016  Overdose Rate 2015  Poverty Rate 2019  \
# 6             0.010891            0.008984          11.428595
# 43            0.021909            0.022330          10.515879
# 47            0.014832            0.012225          17.060648
# 19            0.326388            0.205074           8.971667
# 34            0.656895            0.511210          13.627532
# 37            0.045815            0.032618          12.032830
# 20            0.075532            0.059379           9.940249
# 29            0.030556            0.021891           9.788598
# 41            0.024736            0.022181          14.858803
# 16            0.166734            0.150974          16.790318
#
#     Poverty Rate 2018  Poverty Rate 2017  Poverty Rate 2016  Poverty Rate 2015
# 6           10.179552          10.471374          10.648261          10.610997
# 43          12.042179          17.710656          12.875238          13.181981
# 47           9.219655          10.716038           9.678599           9.726015
# 19          10.725835          12.889035          11.125447          11.048924
# 34          15.996687           9.758941          17.004320          17.045209
# 37          15.612688          14.239385          17.297145          17.877505
# 20          10.176302          16.157475          11.491144          12.110062
# 29          15.722492          12.019658          17.323663          17.776314
# 41          13.685411          11.588556          14.533465          14.889570
# 16          13.090992          15.725732          13.547843          13.627652

# %%
# Cleaner dfs
#Top ten state overdose rates in 2019
top102019 = overdose2019_top10[["State", "Overdose Rate 2019"]]
top102019.reset_index(drop=True)

#Top ten state overdose rates in 2018
top102018 = overdose2018_top10[["State", "Overdose Rate 2018"]]
top102018.reset_index(drop=True)

#Top ten state overdose rates in 2017
top102017 = overdose2017_top10[["State", "Overdose Rate 2017"]]
top102017.reset_index(drop=True)

#Top ten state overdose rates in 2016
top102016 = overdose2016_top10[["State", "Overdose Rate 2016"]]
top102016.reset_index(drop=True)

#Top ten state overdose rates in 2015
top102015 = overdose2015_top10[["State", "Overdose Rate 2015"]]
top102015.reset_index(drop=True)

#5 year total top ten
five_yeartop10 = comparison_df.sort_values(by=['5-Year total'], ascending=False).head(10).reset_index(drop=True)
# Out:
#            State  2019  2018  2017  2016  2015  5-Year total  \
# 0     California  6198  5348  4868  4654  4659         25727
# 1        Florida  5268  4698  5088  4728  3228         23010
# 2   Pennsylvania  4377  4415  5388  4627  3264         22071
# 3           Ohio  4251  3980  5111  4329  3310         20981
# 4       New York  3617  3697  3921  3638  2754         17627
# 5          Texas  3136  3005  2989  2831  2588         14549
# 6       Illinois  2790  2722  2778  2411  1835         12536
# 7       Michigan  2385  2591  2694  2347  1980         11997
# 8     New Jersey  2805  2900  2685  2056  1454         11900
# 9  Massachusetts  2210  2241  2168  2227  1724         10570
#
#    Overdose Rate 2019  Overdose Rate 2018  Overdose Rate 2017  \
# 0            0.015778            0.182972            0.168576
# 1            0.025204            0.046260            0.688903
# 2            0.034218            0.042875            0.325092
# 3            0.036472            0.581448            0.142190
# 4            0.018480            0.009443            0.113031
# 5            0.011097            0.095930            0.102933
# 6            0.021847            0.066684            0.014032
# 7            0.023933            0.030795            0.314924
# 8            0.031593            0.041747            0.046589
# 9            0.032260            0.073588            0.044304
#
#    Overdose Rate 2016  Overdose Rate 2015  Poverty Rate 2019  \
# 0            0.163921            0.166474          13.109174
# 1            0.047561            0.032787          13.733313
# 2            0.045815            0.032618          12.032830
# 3            0.656895            0.511210          13.627532
# 4            0.009412            0.007168          13.699332
# 5            0.091129            0.083659          14.409309
# 6            0.060543            0.046583          12.198873
# 7            0.028242            0.023981          14.034017
# 8            0.030556            0.021891           9.788598
# 9            0.075532            0.059379           9.940249
#
#    Poverty Rate 2018  Poverty Rate 2017  Poverty Rate 2016  Poverty Rate 2015
# 0          13.460531          14.033989          14.696433          15.233742
# 1          15.005961           9.935483          16.414166          16.936603
# 2          15.612688          14.239385          17.297145          17.877505
# 3          15.996687           9.758941          17.004320          17.045209
# 4          14.016130          44.486494          15.533257          15.968007
# 5          11.289198          12.441715          11.904632          12.085982
# 6          13.847499          14.690562          15.423953          16.169315
# 7          10.620442          13.429868          11.090621          11.164628
# 8          15.722492          12.019658          17.323663          17.776314
# 9          10.176302          16.157475          11.491144          12.110062

# %%
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# %%
state = five_yeartop10["State"]
rates = five_yeartop10["5-Year total"]

x_axis = np.arange(len(rates))

plt.bar(x_axis, rates, color="b", alpha = .75, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten State Overdose Totals 2015-2019")
plt.ylabel("Overdoses")
plt.xlabel("State")

plt.show()

#plt.savefig("overdose_totals.png")

# %%
state = top102019["State"]
rates = top102019["Overdose Rate 2019"]

x_axis = np.arange(len(rates))

plt.bar(x_axis, rates, color="b", alpha = 1, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten Overdose Rate States in 2019")
plt.ylabel("Overdose Rate")
plt.xlabel("State")

plt.show()

# %%
state = top102018["State"]
rates = top102018["Overdose Rate 2018"]

x_axis = np.arange(len(rates))

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten Overdose Rate States in 2018")
plt.ylabel("Overdose Rate")
plt.xlabel("State")

plt.bar(x_axis, rates, color="Red", alpha = 1, align="center")
plt.show()

# %%
state = top102017["State"]
rates = top102017["Overdose Rate 2017"]

x_axis = np.arange(len(rates))

plt.bar(x_axis, rates, color="y", alpha = 1, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten Overdose Rate States in 2017")
plt.ylabel("Overdose Rate")
plt.xlabel("State")

plt.show()

# %%
state = top102016["State"]
rates = top102016["Overdose Rate 2016"]

x_axis = np.arange(len(rates))

plt.bar(x_axis, rates, color="g", alpha = 1, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten Overdose Rate States in 2016")
plt.ylabel("Overdose Rate")
plt.xlabel("State")

plt.show()

# %%
state = top102015["State"]
rates = top102015["Overdose Rate 2015"]

x_axis = np.arange(len(rates))

plt.bar(x_axis, rates, color="grey", alpha = .5, align="center")

tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, state, rotation='vertical')

plt.title("Top Ten Overdose Rate States in 2015")
plt.ylabel("Overdose Rate")
plt.xlabel("State")

plt.show()

# %%
overdose_rates_2019 = top102019["Overdose Rate 2019"]
overdose_rates_2018 = top102018["Overdose Rate 2018"]
overdose_rates_2017 = top102017["Overdose Rate 2017"]
overdose_rates_2016 = top102016["Overdose Rate 2016"]
overdose_rates_2015 = top102015["Overdose Rate 2015"]
plt.rcParams["figure.figsize"] = (15,12)
data_to_plot =[overdose_rates_2019, overdose_rates_2018, overdose_rates_2017, overdose_rates_2016, overdose_rates_2015]
year = ["2019", "2018", "2017", "2016", "2015",]
fig1, ax1 = plt.subplots()

ax1.set_title('Overdose Rates by State in the US', fontsize= '16')
ax1.set_ylabel("Percent of a State's Population", fontsize= '16')
ax1.set_xlabel('Year', fontsize= '16')
ax1.boxplot(data_to_plot, labels=year, widths =.75, vert = True)
plt.show()

#plt.savefig("overdose_boxplots.png")
